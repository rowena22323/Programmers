# %%
library(class)
library(gmodels)

# %%
df1<-read.csv("rexp/diabetes.csv")

# %%
head(df1)
# Out:
#   X.0.294118 X0.487437 X0.180328  X.0.292929 X0        X0.00149028 X.0.53117
# 1 -0.8823530 -0.145729  0.0819672 -0.414141   0.000000 -0.2071530  -0.766866
# 2 -0.0588235  0.839196  0.0491803  0.000000   0.000000 -0.3055140  -0.492741
# 3 -0.8823530 -0.105528  0.0819672 -0.535354  -0.777778 -0.1624440  -0.923997
# 4  0.0000000  0.376884 -0.3442620 -0.292929  -0.602837  0.2846500   0.887276
# 5 -0.4117650  0.165829  0.2131150  0.000000   0.000000 -0.2369600  -0.894962
# 6 -0.6470590 -0.216080 -0.1803280 -0.353535  -0.791962 -0.0760059  -0.854825
#   X.0.0333333 X0.1
# 1 -0.666667   1
# 2 -0.633333   0
# 3  0.000000   1
# 4 -0.600000   0
# 5 -0.700000   1
# 6 -0.833333   0

# %%
df <- df1[-9]
str(df)
# Out:
# 'data.frame':	758 obs. of  8 variables:
#  $ X.0.294118 : num  -0.8824 -0.0588 -0.8824 0 -0.4118 ...
#  $ X0.487437  : num  -0.146 0.839 -0.106 0.377 0.166 ...
#  $ X0.180328  : num  0.082 0.0492 0.082 -0.3443 0.2131 ...
#  $ X.0.292929 : num  -0.414 0 -0.535 -0.293 0 ...
#  $ X0         : num  0 0 -0.778 -0.603 0 ...
#  $ X0.00149028: num  -0.207 -0.306 -0.162 0.285 -0.237 ...
#  $ X.0.53117  : num  -0.767 -0.493 -0.924 0.887 -0.895 ...
#  $ X.0.0333333: num  -0.667 -0.633 0 -0.6 -0.7 ...

# %%
df_train <- df[1:530,]
df_test <- df[531:758,]

# %%
df_train_label <- df1[1:530, 9]
df_test_label <- df1[531:758, 9]

# %%
df_test_pred <- knn(train=df_train, test=df_test, cl=df_train_label, k=3)

# %%
CrossTable(x=df_test_label, y=df_test_pred)
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# | Chi-square contribution |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  228
#
#
#               | df_test_pred
# df_test_label |         0 |         1 | Row Total |
# --------------|-----------|-----------|-----------|
#             0 |        46 |        33 |        79 |
#               |    22.363 |     9.306 |           |
#               |     0.582 |     0.418 |     0.346 |
#               |     0.687 |     0.205 |           |
#               |     0.202 |     0.145 |           |
# --------------|-----------|-----------|-----------|
#             1 |        21 |       128 |       149 |
#               |    11.857 |     4.934 |           |
#               |     0.141 |     0.859 |     0.654 |
#               |     0.313 |     0.795 |           |
# ...

# %%
for (kk in 1:51) {
    CrossTable(x=df_test_label, y= knn(train=df_train, test=df_test, cl=df_train_label, k=kk))
}
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# | Chi-square contribution |
# |           N / Row Total |
# |           N / Col Total |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  228
#
#
#               | knn(train = df_train, test = df_test, cl = df_train_label, k = kk)
# df_test_label |         0 |         1 | Row Total |
# --------------|-----------|-----------|-----------|
#             0 |        38 |        41 |        79 |
#               |    10.012 |     4.079 |           |
#               |     0.481 |     0.519 |     0.346 |
#               |     0.576 |     0.253 |           |
#               |     0.167 |     0.180 |           |
# --------------|-----------|-----------|-----------|
#             1 |        28 |       121 |       149 |
#               |     5.309 |     2.163 |           |
#               |     0.188 |     0.812 |     0.654 |
# ...
